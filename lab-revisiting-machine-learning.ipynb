# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/A73547/Ironhack/Unit-7/7.01/learningSet.csv')

# %%
data.shape
# Out:
# (95412, 481)

# %%
data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
data['GENDER']
# Out:
# 0        F
# 1        M
# 2        M
# 3        F
# 4        F
#         ..
# 95407    M
# 95408    M
# 95409    M
# 95410    F
# 95411    F
# Name: GENDER, Length: 95412, dtype: object

# %%
data.describe()#['TARGET_D']
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %% [markdown]
# Null Vlaues in all columns

# %%
data.isna().sum()
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
drop_list =[]

# %% [markdown]
# Adding the 2 columes OSOURCE and ZIP to the empty drop_list

# %%
drop_list1 = drop_list + ['OSOURCE', 'ZIP']

# %%
drop_list1
# Out:
# ['OSOURCE', 'ZIP']

# %%
nulls = pd.DataFrame(data.isna().sum()*100/len(data), columns=['percentage'])
nulls.sort_values('percentage', ascending = False).head(50)
# Out:
#           percentage
# RDATE_5    99.990567
# RAMNT_5    99.990567
# RDATE_3    99.746363
# RAMNT_3    99.746363
# RDATE_4    99.705488
# RAMNT_4    99.705488
# RAMNT_6    99.186685
# RDATE_6    99.186685
# RAMNT_15   92.388798
# RDATE_15   92.388798
# RDATE_23   91.763091
# RAMNT_23   91.763091
# RDATE_20   91.732696
# RAMNT_20   91.732696
# RAMNT_7    90.677273
# RDATE_7    90.677273
# RAMNT_17   90.146942
# RDATE_17   90.146942
# RDATE_21   90.029556
# RAMNT_21   90.029556
# RAMNT_10   89.035970
# RDATE_10   89.035970
# RDATE_13   87.160944
# RAMNT_13   87.160944
# NUMCHLD    87.018404
# RDATE_11   84.551209
# RAMNT_11   84.551209
# RDATE_19   83.359535
# RAMNT_19   83.359535
# RAMNT_9    82.461326
# RDATE_9    82.461326
# RDATE_24   81.409047
# RAMNT_24   81.409047
# RAMNT_18   79.270951
# RDATE_18   79.270951
# RAMNT_22   78.123297
# RDATE_22   78.123297
# RAMNT_8    77.495493
# RDATE_8    77.495493
# RDATE_14   75.561774
# RAMNT_14   75.561774
# RAMNT_12   73.064185
# ...

# %% [markdown]
# creating list for columns with >85% nulls

# %%
cols_to_drop = list(nulls[nulls['percentage'] > 15].index)
len(cols_to_drop)
cols_to_drop
# Out:
# ['AGE',
#  'NUMCHLD',
#  'INCOME',
#  'WEALTH1',
#  'MBCRAFT',
#  'MBGARDEN',
#  'MBBOOKS',
#  'MBCOLECT',
#  'MAGFAML',
#  'MAGFEM',
#  'MAGMALE',
#  'PUBGARDN',
#  'PUBCULIN',
#  'PUBHLTH',
#  'PUBDOITY',
#  'PUBNEWFN',
#  'PUBPHOTO',
#  'PUBOPP',
#  'WEALTH2',
#  'ADATE_5',
#  'ADATE_10',
#  'ADATE_13',
#  'ADATE_14',
#  'ADATE_15',
#  'ADATE_16',
#  'ADATE_17',
#  'ADATE_18',
#  'ADATE_19',
#  'ADATE_20',
#  'ADATE_21',
#  'ADATE_22',
#  'ADATE_23',
#  'ADATE_24',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_8',
#  'RDATE_9',
#  'RDATE_10',
#  'RDATE_11',
#  'RDATE_12',
#  'RDATE_13',
#  'RDATE_14',
#  'RDATE_15',
#  'RDATE_16',
#  'RDATE_17',
#  'RDATE_18',
#  'RDATE_19',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_22',
#  'RDATE_23',
#  'RDATE_24',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_8',
#  'RAMNT_9',
#  'RAMNT_10',
#  'RAMNT_11',
#  'RAMNT_12',
#  'RAMNT_13',
#  'RAMNT_14',
#  'RAMNT_15',
# ...

# %% [markdown]
# Merging drop_list1 with cols_to_drop

# %%
drop_list2 = drop_list1 + cols_to_drop

# %%
drop_list2
# Out:
# ['OSOURCE',
#  'ZIP',
#  'AGE',
#  'NUMCHLD',
#  'INCOME',
#  'WEALTH1',
#  'MBCRAFT',
#  'MBGARDEN',
#  'MBBOOKS',
#  'MBCOLECT',
#  'MAGFAML',
#  'MAGFEM',
#  'MAGMALE',
#  'PUBGARDN',
#  'PUBCULIN',
#  'PUBHLTH',
#  'PUBDOITY',
#  'PUBNEWFN',
#  'PUBPHOTO',
#  'PUBOPP',
#  'WEALTH2',
#  'ADATE_5',
#  'ADATE_10',
#  'ADATE_13',
#  'ADATE_14',
#  'ADATE_15',
#  'ADATE_16',
#  'ADATE_17',
#  'ADATE_18',
#  'ADATE_19',
#  'ADATE_20',
#  'ADATE_21',
#  'ADATE_22',
#  'ADATE_23',
#  'ADATE_24',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_8',
#  'RDATE_9',
#  'RDATE_10',
#  'RDATE_11',
#  'RDATE_12',
#  'RDATE_13',
#  'RDATE_14',
#  'RDATE_15',
#  'RDATE_16',
#  'RDATE_17',
#  'RDATE_18',
#  'RDATE_19',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_22',
#  'RDATE_23',
#  'RDATE_24',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_8',
#  'RAMNT_9',
#  'RAMNT_10',
#  'RAMNT_11',
#  'RAMNT_12',
#  'RAMNT_13',
#  'RAMNT_14',
# ...

# %%
data1 = data.copy()
data1
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
data1 = data1.drop(columns=drop_list2)

# %%
data1.shape
# Out:
# (95412, 402)

# %%
data1
# Out:
#        ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3  \
# 0         8901      0    IL                    3712      0
# 1         9401      1    CA                    5202      0
# 2         9001      1    NC                       0      0
# 3         8701      0    CA                    2801      0
# 4         8601      0    FL                    2001      0        X     X
# ...        ...    ...   ...      ...      ...   ...    ...      ...   ...
# 95407     9601      1    AK                       0      0
# 95408     9601      1    TX                    5001      0
# 95409     9501      1    MI                    3801      0              X
# 95410     8601      0    CA                    4005      0        X
# 95411     8801      2    NC                    1801      0        X
#
#       RECPGVG  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F  \
# 0              ...      0.0        0      L      4      E        X        X
# ...

# %% [markdown]
# Categoricals

# %%
categorical = data.select_dtypes('object')
categorical
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081                        0
# 1         BOA    CA  91326                        0
# 2         AMH    NC  27017                        0
# 3         BRY    CA  95953                        0
# 4                FL  33176                        0        X     X
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504                        0
# 95408     DCD    TX  77379                        0
# 95409     MBC    MI  48910                        0              X
# 95410     PRV    CA  91320                        0        X
# 95411     MCC    NC  28409                        0        X             X
#
#       RECSWEEP  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# 0               ...    S4E    S4E    S4E    S4E      L      E        X
# 1               ...    N1E    N1E           F1E      L      G        X
# ...

# %%
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95412 entries, 0 to 95411
# Data columns (total 74 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OSOURCE   95412 non-null  object
#  1   STATE     95412 non-null  object
#  2   ZIP       95412 non-null  object
#  3   MAILCODE  95412 non-null  object
#  4   PVASTATE  95412 non-null  object
#  5   NOEXCH    95412 non-null  object
#  6   RECINHSE  95412 non-null  object
#  7   RECP3     95412 non-null  object
#  8   RECPGVG   95412 non-null  object
#  9   RECSWEEP  95412 non-null  object
#  10  MDMAUD    95412 non-null  object
#  11  DOMAIN    95412 non-null  object
#  12  CLUSTER   95412 non-null  object
#  13  AGEFLAG   95412 non-null  object
#  14  HOMEOWNR  95412 non-null  object
#  15  CHILD03   95412 non-null  object
#  16  CHILD07   95412 non-null  object
#  17  CHILD12   95412 non-null  object
#  18  CHILD18   95412 non-null  object
#  19  GENDER    95412 non-null  object
# ...

# %%
data['GENDER'].isna().sum()
# Out:
# 0

# %%
print(categorical['GENDER'].value_counts())
categorical['GENDER'] = categorical['GENDER'].fillna('F')
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %% [markdown]
# Reduce the number of categories in the column GENDER to M, F and O

# %%
data["GENDER"] = data["GENDER"].apply(lambda x: "F" if x == "F" else "M" if x == "M" else "O")

# %%
data['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
# O     5041
# Name: GENDER, dtype: int64
